# %%
import torch
import gymnasium as gym
import numpy as np
from torch import nn
import torch.distributions as dist
from torch.utils.data import Dataset, DataLoader
import gymnasium as gym
import ale_py

from rollout_buffer import RolloutBuffer
from python_dataset import PythonListDataset
from model import PPOActorCritic
from learner import PPOLearning
import time
from tqdm import tqdm
import torch.multiprocessing as mp
from learner_process import learner_process
from worker_process import worker_process

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

gym.register_envs(ale_py)
# Out:
# cpu

# %%
# !pip install "gymnasium[atari, accept-rom-license]"
# Out:
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /home/theorcos239/miniconda3/envs/nn-env/lib/python3.10/site-packages (1.2.2)
# WARNING: gymnasium 1.2.2 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /home/theorcos239/miniconda3/envs/nn-env/lib/python3.10/site-packages (from gymnasium[accept-rom-license,atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/theorcos239/miniconda3/envs/nn-env/lib/python3.10/site-packages (from gymnasium[accept-rom-license,atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/theorcos239/miniconda3/envs/nn-env/lib/python3.10/site-packages (from gymnasium[accept-rom-license,atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/theorcos239/miniconda3/envs/nn-env/lib/python3.10/site-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /home/theorcos239/miniconda3/envs/nn-env/lib/python3.10/site-packages (from gymnasium[accept-rom-license,atari]) (0.11.2)

# %%
import time
import queue
import pickle
import torch
import torch.multiprocessing as mp

from worker_process import worker_process
from learner_process import learner_process

def test(frequency=1, maxsize=16, duration_seconds=None, max_iterations=50):
    torch.set_num_threads(1)
    
    try:
        mp.set_start_method("spawn", force=True)
    except RuntimeError:
        pass

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    cpu_device = torch.device("cpu") 

    manager = mp.Manager()
    shared_weights_dict = manager.dict()
    stop_event = mp.Event()

    rollout_queue = mp.Queue(maxsize=maxsize)
    results_queue = mp.Queue()

    num_workers = 4 
    workers = []

    print(f"Launching {num_workers} workers...")
    for wid in range(num_workers):
        p = mp.Process(
            target=worker_process,
            args=(wid, rollout_queue, shared_weights_dict, stop_event, 6, cpu_device, maxsize)
        )
        p.start()
        workers.append(p)

    print("Launching learner...")
    learner = mp.Process(
        target=learner_process,
        args=(rollout_queue, shared_weights_dict, stop_event, 6, frequency, device, results_queue, max_iterations)
    )
    learner.start()

    collected_results = []
    learner_finished = False
    start_time = time.time()

    print("Collecting results...")
    
    while not learner_finished:
        try:
            msg = results_queue.get(timeout=1.0)
            
            if msg == "DONE":
                learner_finished = True
                print("Main: Received DONE signal.")
            else:
                collected_results.append(msg)
                
        except queue.Empty:
            if not learner.is_alive() and results_queue.empty():
                print("Main: Learner died unexpectedly!")
                learner_finished = True
            
            if duration_seconds and (time.time() - start_time > duration_seconds):
                print("Main: Time limit reached.")
                stop_event.set() # Сигнал всем остановиться
                learner_finished = True

    print("Terminating processes...")
    stop_event.set()
 
    time.sleep(1)
    
    if learner.is_alive(): learner.terminate()
    learner.join()

    for w in workers:
        if w.is_alive(): w.terminate()
        w.join()

    filename = f"results_async_fr{frequency}_ms{maxsize}.pkl"
    try:
        with open(filename, 'wb') as file:
            pickle.dump(collected_results, file)
        print(f"Saved {len(collected_results)} entries to {filename}")
    except Exception as e:
        print(f"Error saving file: {e}")

    return collected_results

# %%
import pandas as pd
import numpy as np

def save_array_to_csv(array, x, y):
    filename = f'results_{x}_{y}.csv'
    df = pd.DataFrame(array, columns=['time', 'iterations', 'updates', 'reward', 'queue_size', 'rollout_version'])
    
    df.to_csv(filename, index=False)
    print(f"Данные сохранены в файл: {filename}")
    print(f"Размер данных: {array.shape}")
    return df

# %%
frequency = 10
maxsize = 10

# %%
results = test(frequency, maxsize, duration_seconds = 1000, max_iterations=1000)

# %%
import os
import pickle
def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

results = load_pkl("./results_async_fr5_ms5_fids.pkl")
print(results)
save_array_to_csv(np.array(results), 5, 5)
